# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Goal
# - Create a metric to assess performance and/or strategy. This can be focused on offensive or defensive players, and on teams or individuals

# %% [markdown]
# Metrics
# - Time to QB
# -
# - Metric that determines

# %%
data_path = r'C:\Users\sully\OneDrive\Desktop\Big-Data-Bowl-2023\data\\'
games_df = pd.read_csv(data_path+'games.csv') # contains teams playing in each game
scouting_df = pd.read_csv(data_path+'pffScoutingData.csv') # contains player-level scouting info for each game and play
players_df = pd.read_csv(data_path+'players.csv') #NFL id, height, weight, birthday, college, position, name
plays_df = pd.read_csv(data_path+'plays.csv') # play-level information

# Tracking data
week1_df = pd.read_csv(data_path+'week1.csv')
week2_df = pd.read_csv(data_path+'week2.csv')
week3_df = pd.read_csv(data_path+'week3.csv')
week4_df = pd.read_csv(data_path+'week4.csv')
week5_df = pd.read_csv(data_path+'week5.csv')
week6_df = pd.read_csv(data_path+'week6.csv')
week7_df = pd.read_csv(data_path+'week7.csv')
week8_df = pd.read_csv(data_path+'week8.csv')

# %%
scouting_df
# Out:
#             gameId  playId  nflId    pff_role pff_positionLinedUp  pff_hit  \
# 0       2021090900      97  25511        Pass                  QB      NaN
# 1       2021090900      97  35481  Pass Route                TE-L      NaN
# 2       2021090900      97  35634  Pass Route                 LWR      NaN
# 3       2021090900      97  39985  Pass Route                HB-R      NaN
# 4       2021090900      97  40151  Pass Block                   C      NaN
# ...            ...     ...    ...         ...                 ...      ...
# 188249  2021110100    4433  52507  Pass Block                  LT      NaN
# 188250  2021110100    4433  52546    Coverage               SCBoR      0.0
# 188251  2021110100    4433  52573  Pass Route               SLoWR      NaN
# 188252  2021110100    4433  52585   Pass Rush                 LEO      0.0
# 188253  2021110100    4433  53449  Pass Route                 LWR      NaN
#
#         pff_hurry  pff_sack  pff_beatenByDefender  pff_hitAllowed  \
# ...
